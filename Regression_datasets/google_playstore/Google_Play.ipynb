# %% [markdown]
# #Import Necessary Libraries

# %%
import numpy as np                      # numpy used for mathematical operation on array
import pandas as pd                     # pandas used for data manipulation on dataframe
import matplotlib.pyplot as plt         # matplotlib used for data visualization
import seaborn as sns                   # seaborn used for data visualization
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# #Reading Dataset

# %%
# Reading Both the datasets with pandas

df1 = pd.read_csv("/content/google_play(1).csv")
df2 = pd.read_csv("/content/google_play(2).csv")

# %%
# Reading first 5 Rows of the dataset 1

df1.head()
# Out:
#    id Reviews Price Content Rating                     Genres  \
# 0   1     159     0       Everyone               Art & Design
# 1   2     967     0       Everyone  Art & Design;Pretend Play
# 2   3   87510     0       Everyone               Art & Design
# 3   4  215644     0           Teen                        NaN
# 4   5     967     0       Everyone                        NaN
#
#        Last Updated         Current Ver   Android Ver
# 0   January 7, 2018               1.0.0  4.0.3 and up
# 1  January 15, 2018               2.0.0  4.0.3 and up
# 2    August 1, 2018               1.2.4  4.0.3 and up
# 3      June 8, 2018  Varies with device    4.2 and up
# 4     June 20, 2018                 1.1    4.4 and up

# %%
# Checking the shape of the dataset 1

df1.shape
# Out:
# (10841, 8)

# %%
# Reading first 5 Rows of the dataset 2

df2.head()
# Out:
#    id                                                App        Category  \
# 0   1     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1   2                                Coloring book moana  ART_AND_DESIGN
# 2   3  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3   4                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4   5              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#   Rating Reviews  Size     Installs  Type
# 0    4.1     159   NaN      10,000+   NaN
# 1    3.9     967   NaN     500,000+  Free
# 2    4.7   87510  8.7M   5,000,000+   NaN
# 3    4.5  215644   25M  50,000,000+  Free
# 4    4.3     967   NaN     100,000+  Free

# %%
# Checking the shape of the dataset 2

df2.shape
# Out:
# (10841, 8)

# %%
# Merging both the dataset 

df = pd.merge(df1, df2, on=['id','Reviews'])

# %%
# Reading first 5 Rows of the data

df.head()
# Out:
#    id Reviews Price Content Rating                     Genres  \
# 0   1     159     0       Everyone               Art & Design
# 1   2     967     0       Everyone  Art & Design;Pretend Play
# 2   3   87510     0       Everyone               Art & Design
# 3   4  215644     0           Teen                        NaN
# 4   5     967     0       Everyone                        NaN
#
#        Last Updated         Current Ver   Android Ver  \
# 0   January 7, 2018               1.0.0  4.0.3 and up
# 1  January 15, 2018               2.0.0  4.0.3 and up
# 2    August 1, 2018               1.2.4  4.0.3 and up
# 3      June 8, 2018  Varies with device    4.2 and up
# 4     June 20, 2018                 1.1    4.4 and up
#
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#    Size     Installs  Type
# 0   NaN      10,000+   NaN
# 1   NaN     500,000+  Free
# 2  8.7M   5,000,000+   NaN
# 3   25M  50,000,000+  Free
# 4   NaN     100,000+  Free

# %%
# Reading last 5 Rows of the data

df.tail()
# Out:
#           id Reviews Price Content Rating     Genres      Last Updated  \
# 10836  10837      38     0       Everyone        NaN     July 25, 2017
# 10837  10838       4     0       Everyone  Education      July 6, 2018
# 10838  10839       3     0       Everyone    Medical  January 20, 2017
# 10839  10840     114     0     Mature 17+        NaN  January 19, 2015
# 10840  10841  398307     0       Everyone  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver  \
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating                Size     Installs  Type
# 10836    4.5                 NaN       5,000+   NaN
# 10837    5.0                 NaN         100+   NaN
# 10838    NaN                9.5M       1,000+  Free
# 10839    4.5  Varies with device       1,000+  Free
# 10840    4.5                 19M  10,000,000+  Free

# %%
# Checking the shape of the data

df.shape
# Out:
# (10841, 14)

# %%
# Checking the info of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10841 non-null  int64
#  1   Reviews         10841 non-null  object
#  2   Price           10841 non-null  object
#  3   Content Rating  10840 non-null  object
#  4   Genres          7812 non-null   object
#  5   Last Updated    10841 non-null  object
#  6   Current Ver     10833 non-null  object
#  7   Android Ver     10838 non-null  object
#  8   App             10841 non-null  object
#  9   Category        10841 non-null  object
#  10  Rating          9454 non-null   object
#  11  Size            5595 non-null   object
#  12  Installs        10841 non-null  object
#  13  Type            8810 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 1.2+ MB

# %%
# Checking the summary statistics of the dataset

df.describe(include='all')
# Out:
#                   id Reviews  Price Content Rating Genres    Last Updated  \
# count   10841.000000   10841  10841          10840   7812           10841
# unique           NaN    6002     93              6    115            1378
# top              NaN       0      0       Everyone  Tools  August 3, 2018
# freq             NaN     596  10040           8714    612             326
# mean     5421.000000     NaN    NaN            NaN    NaN             NaN
# std      3129.671468     NaN    NaN            NaN    NaN             NaN
# min         1.000000     NaN    NaN            NaN    NaN             NaN
# 25%      2711.000000     NaN    NaN            NaN    NaN             NaN
# 50%      5421.000000     NaN    NaN            NaN    NaN             NaN
# 75%      8131.000000     NaN    NaN            NaN    NaN             NaN
# max     10841.000000     NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver     App Category Rating  \
# count                10833       10838   10841    10841   9454
# unique                2832          33    9660       34     41
# top     Varies with device  4.1 and up  ROBLOX   FAMILY    4.4
# freq                  1459        2451       9     1972   1046
# mean                   NaN         NaN     NaN      NaN    NaN
# std                    NaN         NaN     NaN      NaN    NaN
# min                    NaN         NaN     NaN      NaN    NaN
# 25%                    NaN         NaN     NaN      NaN    NaN
# 50%                    NaN         NaN     NaN      NaN    NaN
# 75%                    NaN         NaN     NaN      NaN    NaN
# max                    NaN         NaN     NaN      NaN    NaN
#
#                       Size    Installs  Type
# count                 5595       10841  8810
# unique                 325          22     3
# top     Varies with device  1,000,000+  Free
# freq                   906        1579  8139
# mean                   NaN         NaN   NaN
# std                    NaN         NaN   NaN
# min                    NaN         NaN   NaN
# 25%                    NaN         NaN   NaN
# 50%                    NaN         NaN   NaN
# 75%                    NaN         NaN   NaN
# max                    NaN         NaN   NaN

# %%
# Checking the null values of the data

df.isnull()
# Out:
#           id  Reviews  Price  Content Rating  Genres  Last Updated  \
# 0      False    False  False           False   False         False
# 1      False    False  False           False   False         False
# 2      False    False  False           False   False         False
# 3      False    False  False           False    True         False
# 4      False    False  False           False    True         False
# ...      ...      ...    ...             ...     ...           ...
# 10836  False    False  False           False    True         False
# 10837  False    False  False           False   False         False
# 10838  False    False  False           False   False         False
# 10839  False    False  False           False    True         False
# 10840  False    False  False           False   False         False
#
#        Current Ver  Android Ver    App  Category  Rating   Size  Installs  \
# 0            False        False  False     False   False   True     False
# 1            False        False  False     False   False   True     False
# 2            False        False  False     False   False  False     False
# 3            False        False  False     False   False  False     False
# 4            False        False  False     False   False   True     False
# ...            ...          ...    ...       ...     ...    ...       ...
# 10836        False        False  False     False   False   True     False
# 10837        False        False  False     False   False   True     False
# 10838        False        False  False     False    True  False     False
# 10839        False        False  False     False   False  False     False
# 10840        False        False  False     False   False  False     False
#
#         Type
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
# ...      ...
# 10836   True
# 10837   True
# 10838  False
# 10839  False
# 10840  False
#
# [10841 rows x 14 columns]

# %%
# We can see the data types of each column in a tabular format.

Data_dict = pd.DataFrame(df.dtypes)
Data_dict
# Out:
#                      0
# id               int64
# Reviews         object
# Price           object
# Content Rating  object
# Genres          object
# Last Updated    object
# Current Ver     object
# Android Ver     object
# App             object
# Category        object
# Rating          object
# Size            object
# Installs        object
# Type            object

# %%
# identifying the missing values of each column in a tabular format.

Data_dict['MissingVal'] = df.isnull().sum()
Data_dict
# Out:
#                      0  MissingVal
# id               int64           0
# Reviews         object           0
# Price           object           0
# Content Rating  object           1
# Genres          object        3029
# Last Updated    object           0
# Current Ver     object           8
# Android Ver     object           3
# App             object           0
# Category        object           0
# Rating          object        1387
# Size            object        5246
# Installs        object           0
# Type            object        2031

# %%
# identifying the unique values of each column in a tabular format.

Data_dict['UniqueVal'] = df.nunique()
Data_dict
# Out:
#                      0  MissingVal  UniqueVal
# id               int64           0      10841
# Reviews         object           0       6002
# Price           object           0         93
# Content Rating  object           1          6
# Genres          object        3029        115
# Last Updated    object           0       1378
# Current Ver     object           8       2832
# Android Ver     object           3         33
# App             object           0       9660
# Category        object           0         34
# Rating          object        1387         41
# Size            object        5246        325
# Installs        object           0         22
# Type            object        2031          3

# %%
# identifying count of the variable.

Data_dict['Count'] = df.count()
Data_dict
# Out:
#                      0  MissingVal  UniqueVal  Count
# id               int64           0      10841  10841
# Reviews         object           0       6002  10841
# Price           object           0         93  10841
# Content Rating  object           1          6  10840
# Genres          object        3029        115   7812
# Last Updated    object           0       1378  10841
# Current Ver     object           8       2832  10833
# Android Ver     object           3         33  10838
# App             object           0       9660  10841
# Category        object           0         34  10841
# Rating          object        1387         41   9454
# Size            object        5246        325   5595
# Installs        object           0         22  10841
# Type            object        2031          3   8810

# %%
# Checking the sum of null values of the data

df.isnull().sum()
# Out:
# id                   0
# Reviews              0
# Price                0
# Content Rating       1
# Genres            3029
# Last Updated         0
# Current Ver          8
# Android Ver          3
# App                  0
# Category             0
# Rating            1387
# Size              5246
# Installs             0
# Type              2031
# dtype: int64

# %%
# Impute "categorical null values" with Mode value

df['Genres'].fillna(df['Genres'].mode()[0], inplace=True)
df['Rating'].fillna(df['Rating'].mode()[0], inplace=True)
df['Size'].fillna(df['Size'].mode()[0], inplace=True)
df['Content Rating'].fillna(df['Content Rating'].mode()[0], inplace=True)
df['Type'].fillna(df['Type'].mode()[0], inplace=True)
df['Current Ver'].fillna(df['Current Ver'].mode()[0], inplace=True)
df['Android Ver'].fillna(df['Android Ver'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# id                0
# Reviews           0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# App               0
# Category          0
# Rating            0
# Size              0
# Installs          0
# Type              0
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Select categorical variables (assuming they are in object data type)
cat_vars = df.select_dtypes(include=['object']).columns.tolist()

# Label encode categorical variables
le = LabelEncoder()
for col in cat_vars:
    df[col] = le.fit_transform(df[col])

# %%
"""
The code generates a grid of subplots where each subplot shows the distribution,
(i.e., histogram) of a variable/column in the df DataFrame.
This type of plot can be useful for exploring the shape and spread of each variable in a dataset.
"""

# Select only the numerical columns
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Create subplots of histograms for each numerical column
n_rows = 4  # Number of rows in the subplot grid
n_cols = 4  # Number of columns in the subplot grid
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 15))
for i, col in enumerate(num_cols):
    r = i // n_cols
    c = i % n_cols
    ax = axes[r][c]
    sns.histplot(df[col], ax=ax)
    ax.set_title(col)
plt.tight_layout()
plt.show()

# %%
"""
Heatmap function to visualize the correlation matrix of the columns.
It hows the pairwise correlations (i.e., linear relationships) between all pairs of variables/columns in the DataFrame.
"""

plt.figure(figsize=(10, 10))
sns.heatmap(df.corr().abs(),annot=True)
# Out:
# <AxesSubplot:>

# %%
for k, v in df.items():
        q1 = v.quantile(0.25)
        q3 = v.quantile(0.75)
        irq = q3 - q1
        v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
        perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
        print("Column %s outliers = %.2f%%" % (k, perc))
# Out:
# Column id outliers = 0.00%
# Column Reviews outliers = 0.00%
# Column Price outliers = 100.00%
# Column Content Rating outliers = 100.00%
# Column Genres outliers = 0.00%
# Column Last Updated outliers = 0.00%
# Column Current Ver outliers = 0.00%
# Column Android Ver outliers = 13.89%
# Column App outliers = 0.00%
# Column Category outliers = 0.00%
# Column Rating outliers = 13.23%
# Column Size outliers = 0.00%
# Column Installs outliers = 0.00%
# Column Type outliers = 100.00%

# %%
# Select numerical variables with outliers (assuming they are in float data type)

num_vars = df.select_dtypes(include=['float','int']).columns.tolist()



# Replace outliers with the maximum and minimum values of each variable

for col in num_vars:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    upper_limit = q3 + 1.5*iqr
    lower_limit = q1 - 1.5*iqr
    df[col] = df[col].apply(lambda x: upper_limit if x > upper_limit else x)
    df[col] = df[col].apply(lambda x: lower_limit if x < lower_limit else x)

# %%
import pandas as pd
import numpy as np

# Define function to treat outliers in a column
def treat_outliers(col):
    mean = np.mean(col)
    std = np.std(col)
    threshold = 3
    outlier_indices = col[np.abs(col - mean) > std * threshold].index
    col[outlier_indices] = mean

# Treat outliers in each column of the dataset
for col in df.columns:
    treat_outliers(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10841 non-null  int64
#  1   Reviews         10841 non-null  float64
#  2   Price           10841 non-null  float64
#  3   Content Rating  10841 non-null  float64
#  4   Genres          10841 non-null  float64
#  5   Last Updated    10841 non-null  float64
#  6   Current Ver     10841 non-null  float64
#  7   Android Ver     10841 non-null  float64
#  8   App             10841 non-null  float64
#  9   Category        10841 non-null  float64
#  10  Rating          10841 non-null  float64
#  11  Size            10841 non-null  float64
#  12  Installs        10841 non-null  float64
#  13  Type            10841 non-null  float64
# dtypes: float64(13), int64(1)
# memory usage: 1.5 MB

# %%
# Split the data into features and target

features = df.drop(['Price'], axis=1).values
target = df['Price'].values.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.33,  random_state = 2)

# %% [markdown]
# ###Comparing the error with SKLearn Lasso Regression

# %%
from sklearn.linear_model import Lasso
sk_model = Lasso()

# %%
sk_model.fit(X_train, y_train)
# Out:
# Lasso()

# %%
sk_train_data_prediction = sk_model.predict(X_train)

# %%
test_data_prediction = sk_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# R squared error
score_1_ = metrics.r2_score(y_test, test_data_prediction)

# Mean Absolute Error
score_2_ = metrics.mean_absolute_error(y_test, test_data_prediction)


print("R squared error : ", score_1_)
print('Mean Absolute Error : ', score_2_)
# Out:
# R squared error :  1.0
# Mean Absolute Error :  0.0

# %% [markdown]
# #LASSO REGRESSION

# %%
# creating a class for Lasso Regression

class Lasso_Regression():

    def __init__(self, learning_rate, no_of_iterations, lambda_parameter):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations
        self.lambda_parameter = lambda_parameter
    
    def set_params(self, **kwargs):
        for key, value in kwargs.items():
            setattr(self, key, value)
        return self

    def fit(self, X, y):
        self.m, self.n = X.shape
        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.y = y

        for i in range(self.no_of_iterations):
            self.update_weights()

    def update_weights(self):
        Y_prediction = self.predict(self.X)

        dw = np.zeros(self.n)
        for i in range(self.n):
            if self.w[i] > 0:
                dw[i] = (-(2 * (self.X[:, i]).dot(self.y - Y_prediction)) + self.lambda_parameter) / self.m
            else:
                dw[i] = (-(2 * (self.X[:, i]).dot(self.y - Y_prediction)) - self.lambda_parameter) / self.m

        db = - 2 * np.sum(self.y - Y_prediction) / self.m

        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db
    
    def predict(self, X):
        return X.dot(self.w) + self.b
    
    def score(self, X, y):
        Y_prediction = self.predict(X)
        return 1 - ((y - Y_prediction) ** 2).sum() / ((y - y.mean()) ** 2).sum()


    


  # Predicting the Target variable
    def predict(self,X):
      return np.dot(X, self.w.reshape(-1,1)) + self.b
  
    def mean_squared_error(self,y_true, y_pred):
   
      # Check if the lengths of both arrays are equal
        if len(y_true) != len(y_pred):
            raise ValueError("Length of y_true and y_pred should be the same.")
      
      # Calculate the squared differences between the true and predicted values
        squared_differences = [(y_true[i] - y_pred[i])**2 for i in range(len(y_true))]
      
      # Calculate the mean of the squared differences
        mse1 = sum(squared_differences) / len(squared_differences)
      
        return mse1
    def r2(self,y_true, y_pred):
    # Calculate the mean of the true values
      y_true_mean = sum(y_true) / len(y_true)
    
    # Calculate the total sum of squares (TSS)
      tss = sum((y_true - y_true_mean) ** 2)
    
    # Calculate the residual sum of squares (RSS)
      rss = sum((y_true - y_pred) ** 2)
    
    # Calculate the R-squared value
      r2_score = 1 - (rss / tss)
    
      return r2_score

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Lasso_Regression(learning_rate= 0.1, no_of_iterations= 200, lambda_parameter= 0.01)

# %%
model.fit(X_train, y_train)

# %%
test_data_prediction = model.predict(X_test)

# %%
from sklearn import metrics

# R squared error
score_1 = model.r2(y_test, test_data_prediction)

# Mean Absolute Error
score_2 = model.mean_squared_error(y_test, test_data_prediction)

print("R squared error : ", score_1)
print('Mean Squared Error : ', score_2)
# Out:
# R squared error :  [-inf]
# Mean Squared Error :  [8.72003654e-14]
